# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import mpld3
#mpld3.enable_notebook()
from mpld3 import plugins
from iex import stock
import requests

#need to really play up the fact that we used a wrapper, which saved us SOOOOO much time
#change BTI to CVX

# %%
A = stock('A').chart_table(range='1y')
A = A.rename(columns={'close':'A'})
AAPL = stock('AAPL').chart_table(range='1y')
AAPL = AAPL.rename(columns={'close':'AAPL'})
AMD = stock('AMD').chart_table(range='1y')
AMD = AMD.rename(columns={'close':'AMD'})
ARQL = stock('ARQL').chart_table(range='1y')
ARQL = ARQL.rename(columns={'close':'ARQL'})
AU = stock('AU').chart_table(range='1y')
AU = AU.rename(columns={'close':'AU'})
BHP = stock('BHP').chart_table(range='1y')
BHP = BHP.rename(columns={'close':'BHP'})
BLIN  = stock('BLIN').chart_table(range='1y')
BLIN = BLIN.rename(columns={'close':'BLIN'})
BOSC = stock('BOSC').chart_table(range='1y')
BOSC = BOSC.rename(columns={'close':'BOSC'})
BP = stock('BP').chart_table(range='1y')
BP = BP.rename(columns={'close':'BP'})
BTI= stock('BTI').chart_table(range='1y')
BTI = BTI.rename(columns={'close':'BTI'})
# Out:
# https://api.iextrading.com/1.0/stock/A/chart/1y
# https://api.iextrading.com/1.0/stock/AAPL/chart/1y
# https://api.iextrading.com/1.0/stock/AMD/chart/1y
# https://api.iextrading.com/1.0/stock/ARQL/chart/1y
# https://api.iextrading.com/1.0/stock/AU/chart/1y
# https://api.iextrading.com/1.0/stock/BHP/chart/1y
# https://api.iextrading.com/1.0/stock/BLIN/chart/1y
# https://api.iextrading.com/1.0/stock/BOSC/chart/1y
# https://api.iextrading.com/1.0/stock/BP/chart/1y
# https://api.iextrading.com/1.0/stock/BTI/chart/1y

# %%
df_1y = A[['date','A']]
df_1y = df_1y.join(AAPL['AAPL'])
df_1y = df_1y.join(AMD['AMD'])
df_1y = df_1y.join(ARQL['ARQL'])
df_1y = df_1y.join(AU['AU'])
df_1y = df_1y.join(BHP['BHP'])
df_1y = df_1y.join(BLIN['BLIN'])
df_1y = df_1y.join(BOSC['BOSC'])
df_1y = df_1y.join(BP['BP'])
df_1y = df_1y.join(BTI['BTI'])
df_1y
# Out:
#            date        A      AAPL    AMD  ARQL       AU      BHP    BLIN  \
# 0    2017-07-10  59.3290  142.8395  13.81  1.29   9.7484  36.0286  2.8995
# 1    2017-07-11  59.2695  143.3023  13.89  1.29   9.8179  36.5359  3.0000
# 2    2017-07-12  60.1912  143.5091  14.29  1.33   9.9571  36.8231  2.8500
# 3    2017-07-13  60.6472  145.5080  13.53  1.30   9.7384  36.9858  2.9500
# 4    2017-07-14  60.9742  146.7586  13.92  1.31   9.7484  37.7133  2.9375
# 5    2017-07-17  61.0040  147.2706  13.80  1.31   9.6788  37.9430  2.9505
# 6    2017-07-18  60.6670  147.7827  13.48  1.27   9.7384  37.7420  2.7505
# 7    2017-07-19  60.8355  148.7083  13.55  1.27   9.5993  38.1057  2.8500
# 8    2017-07-20  60.4390  148.0387  13.80  1.28   9.4900  37.5314  2.8500
# 9    2017-07-21  60.8256  147.9698  13.88  1.28   9.6192  37.1294  2.9250
# 10   2017-07-24  60.9544  149.7619  14.16  1.23   9.3906  37.2251  2.7805
# 11   2017-07-25  60.0029  150.4019  14.11  1.21   9.5198  38.4886  3.1000
# ...

# %%
A_2 = stock('A').chart_table(range='2y')
A_2 = A_2.rename(columns={'close':'A'})
AAPL_2 = stock('AAPL').chart_table(range='2y')
AAPL_2 = AAPL_2.rename(columns={'close':'AAPL'})
AMD_2 = stock('AMD').chart_table(range='2y')
AMD_2 = AMD_2.rename(columns={'close':'AMD'})
ARQL_2 = stock('ARQL').chart_table(range='2y')
ARQL_2 = ARQL_2.rename(columns={'close':'ARQL'})
AU_2 = stock('AU').chart_table(range='2y')
AU_2 = AU_2.rename(columns={'close':'AU'})
BHP_2 = stock('BHP').chart_table(range='2y')
BHP_2 = BHP_2.rename(columns={'close':'BHP'})
BLIN_2  = stock('BLIN').chart_table(range='2y')
BLIN_2 = BLIN_2.rename(columns={'close':'BLIN'})
BOSC_2 = stock('BOSC').chart_table(range='2y')
BOSC_2 = BOSC_2.rename(columns={'close':'BOSC'})
BP_2 = stock('BP').chart_table(range='2y')
BP_2 = BP_2.rename(columns={'close':'BP'})
BTI_2 = stock('BTI').chart_table(range='2y')
BTI_2 = BTI_2.rename(columns={'close':'BTI'})
# Out:
# https://api.iextrading.com/1.0/stock/A/chart/2y
# https://api.iextrading.com/1.0/stock/AAPL/chart/2y
# https://api.iextrading.com/1.0/stock/AMD/chart/2y
# https://api.iextrading.com/1.0/stock/ARQL/chart/2y
# https://api.iextrading.com/1.0/stock/AU/chart/2y
# https://api.iextrading.com/1.0/stock/BHP/chart/2y
# https://api.iextrading.com/1.0/stock/BLIN/chart/2y
# https://api.iextrading.com/1.0/stock/BOSC/chart/2y
# https://api.iextrading.com/1.0/stock/BP/chart/2y
# https://api.iextrading.com/1.0/stock/BTI/chart/2y

# %%
df_2y = A_2[['date','A']]
df_2y = df_2y.join(AAPL_2['AAPL'])
df_2y = df_2y.join(AMD_2['AMD'])
df_2y = df_2y.join(ARQL_2['ARQL'])
df_2y = df_2y.join(AU_2['AU'])
df_2y = df_2y.join(BHP_2['BHP'])
df_2y = df_2y.join(BLIN_2['BLIN'])
df_2y = df_2y.join(BOSC_2['BOSC'])
df_2y = df_2y.join(BP_2['BP'])
df_2y = df_2y.join(BTI_2['BTI'])

# %%
A_5 = stock('A').chart_table(range='5y')
A_5 = A_5.rename(columns={'close':'A'})
AAPL_5 = stock('AAPL').chart_table(range='5y')
AAPL_5 = AAPL_5.rename(columns={'close':'AAPL'})
AMD_5 = stock('AMD').chart_table(range='5y')
AMD_5 = AMD_5.rename(columns={'close':'AMD'})
ARQL_5 = stock('ARQL').chart_table(range='5y')
ARQL_5 = ARQL_5.rename(columns={'close':'ARQL'})
AU_5 = stock('AU').chart_table(range='5y')
AU_5 = AU_5.rename(columns={'close':'AU'})
BHP_5 = stock('BHP').chart_table(range='5y')
BHP_5 = BHP_5.rename(columns={'close':'BHP'})
BLIN_5  = stock('BLIN').chart_table(range='5y')
BLIN_5 = BLIN_5.rename(columns={'close':'BLIN'})
BOSC_5 = stock('BOSC').chart_table(range='5y')
BOSC_5 = BOSC_5.rename(columns={'close':'BOSC'})
BP_5 = stock('BP').chart_table(range='5y')
BP_5 = BP_5.rename(columns={'close':'BP'})
BTI_5 = stock('BTI').chart_table(range='5y')
BTI_5 = BTI_5.rename(columns={'close':'CVX'})
# Out:
# https://api.iextrading.com/1.0/stock/A/chart/5y
# https://api.iextrading.com/1.0/stock/AAPL/chart/5y
# https://api.iextrading.com/1.0/stock/AMD/chart/5y
# https://api.iextrading.com/1.0/stock/ARQL/chart/5y
# https://api.iextrading.com/1.0/stock/AU/chart/5y
# https://api.iextrading.com/1.0/stock/BHP/chart/5y
# https://api.iextrading.com/1.0/stock/BLIN/chart/5y
# https://api.iextrading.com/1.0/stock/BOSC/chart/5y
# https://api.iextrading.com/1.0/stock/BP/chart/5y
# https://api.iextrading.com/1.0/stock/BTI/chart/5y

# %%
df_5y = A_5[['date','A']]
df_5y = df_5y.join(AAPL_5['AAPL'])
df_5y = df_5y.join(AMD_5['AMD'])
df_5y = df_5y.join(ARQL_5['ARQL'])
df_5y = df_5y.join(AU_5['AU'])
df_5y = df_5y.join(BHP_5['BHP'])
df_5y = df_5y.join(BLIN_5['BLIN'])
df_5y = df_5y.join(BOSC_5['BOSC'])
df_5y = df_5y.join(BP_5['BP'])
df_5y = df_5y.join(BTI_5['CVX'])

# %%
df_1y_date = df_1y['date'].values.tolist()
df_1y_a = df_1y['A'].values.tolist()
df_1y_aapl = df_1y['AAPL'].values.tolist()
df_1y_amd = df_1y['AMD'].values.tolist()
df_1y_arql = df_1y['ARQL'].values.tolist()
df_1y_au = df_1y['AU'].values.tolist()
df_1y_bhp = df_1y['BHP'].values.tolist()
df_1y_blin = df_1y['BLIN'].values.tolist()
df_1y_bosc = df_1y['BOSC'].values.tolist()
df_1y_bp = df_1y['BP'].values.tolist()
df_1y_bti = df_1y['CVX'].values.tolist()

# %%
fig, ax = plt.subplots()
ax.set_title('Stocks')
plt.plot(df_1y['date'].tolist(), df_1y_a)
plt.plot(df_1y['date'].tolist(), df_1y_aapl)
plt.plot(df_1y['date'].tolist(), df_1y_amd)
plt.plot(df_1y['date'].tolist(), df_1y_arql)
plt.plot(df_1y['date'].tolist(), df_1y_au)
plt.plot(df_1y['date'].tolist(), df_1y_bhp)
plt.plot(df_1y['date'].tolist(), df_1y_blin)
plt.plot(df_1y['date'].tolist(), df_1y_bosc)
plt.plot(df_1y['date'].tolist(), df_1y_bp)
plt.plot(df_1y['date'].tolist(), df_1y_bti)

ax.set_xlabel('Date')
ax.set_ylabel('Stock Price')
labels = ["Day of year {0}".format(i) for i in range(366)]

handles, labels = ax.get_legend_handles_labels() # return lines and labels
interactive_legend = plugins.InteractiveLegendPlugin(zip(handles,
                                                         ax.collections),
                                                     labels,
                                                     alpha_unsel=0.5,
                                                     alpha_over=1.5, 
                                                     start_visible=True)
plugins.connect(fig, interactive_legend)

#tooltip = plugins.PointLabelTooltip(points, labels)
#plugins.connect(fig, tooltip)

mpld3.show()
# Out:
# Note: if you're in the IPython notebook, mpld3.show() is not the best command
#       to use. Consider using mpld3.display(), or mpld3.enable_notebook().
#       See more information at http://mpld3.github.io/quickstart.html .
#
# You must interrupt the kernel to end this command
#
# Serving to http://127.0.0.1:8889/    [Ctrl-C to exit]
# 127.0.0.1 - - [11/Jul/2018 20:59:20] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jul/2018 20:59:20] "GET /d3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jul/2018 20:59:20] "GET /mpld3.js HTTP/1.1" 200 -

# %%
df_1y
